# %%
library(destiny)
data(guo_norm)
# Out:
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo

# %%
dm_guo <- DiffusionMap(guo_norm)
plot(dm_guo, 1:2, col_by = 'num_cells', pal = hcl.colors)
# Out:
# plot without title
